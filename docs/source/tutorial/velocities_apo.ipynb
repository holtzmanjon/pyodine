# %% [markdown]
# # Weight and combine the chunk velocities

# %% [markdown]
# ## Background

# %% [markdown]
# We have modelled all observations of our star and saved the results to file. To retrieve the RV timeseries of the star, we still need to combine the individual best-fit velocities of all 522 chunks for each observation. One might think of a simple mean or median over the chunk velocities within each observation to achieve this - but as we have seen [in the previous chapter](./observation.ipynb) we have quite a number of 'bad' chunks, with outlier velocities and huge errors. Also, some chunks contain more spectral information than others, deliver therefore more realistic results and should be weighted higher than poorly constraint outlier chunks.
#
# In this script, we show how to run the combination routine. For a sound mathematical description, please check out our !!!paper!!!. But basically, weights are created for each chunk not only based on their 'velocity performance' within one observation, but also based on their performance throughout the whole timeseries. I.e. if the velocity timeseries of one chunk with index $i$ shows a highly significant scatter around the mean timeseries of all chunk velocities, that chunk receives lower weight *in all observations*!

# %% [markdown]
# ## Run the code

# %% [markdown]
# First of, as before, we set up the path structure and import the velocity combination routine:

# %%
# Automatic reloading of imports
# %load_ext autoreload
# %autoreload 2

import sys
import os
import matplotlib.pyplot as plt
import numpy as np

# Put in the pyodine path on your machine here!
pyodine_path = '/home/holtz/git/pyodine/'

sys.path.append(pyodine_path)

import pyodine
import pyodine_combine_vels             # <- the velocity combination routine
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Again we load an object which contains all the important parameters for the velocity combination - this is the `Timeseries_Parameters` object:

# %%
import utilities_apo as utilities

Pars = utilities.timeseries_parameters.Timeseries_Parameters()

# %% [markdown]
# Next, we need to specify the pathnames for the saved model results to use. We can also define pathnames for a directory where to save analysis plots, for a log-file with diagnosis information, and a text-file where to save the RV timeseries results in a human-readable format. Also, the combined model results (including best-fit results for all observations and chunks, and the RV timeseries along with additional information), represented as a `CombinedResults` object, can be saved to a HDF5-file whose pathname we also specify below.

# %%
# Individual result files to use
parent_dir = os.path.join(pyodine_path, 'apo_data/obs_results')
#res_files = [os.path.join(parent_dir, f, f+'_res1.h5') for f in os.listdir(parent_dir)]
import glob
res_files = glob.glob(parent_dir+'/UT*/*/*_res1.h5')
res_files.sort()

# The directory for analysis plots
plot_dir = os.path.join(pyodine_path, 'apo_data/vel_results')

# The output name of the CombinedResults object
comb_res_out = os.path.join(plot_dir, 'apo_comb.h5')

# The output name of the velocity results text file
vels_out = os.path.join(plot_dir, 'apo.vels')

# Log files
error_file = os.path.join(plot_dir, 'error.log')
info_file  = os.path.join(plot_dir, 'info.log')

# %%
res_files
# Out:
# ['/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0173/HD23249_ec.0173_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0174/HD23249_ec.0174_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0175/HD23249_ec.0175_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0185/HD23249_ec.0185_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0197/HD23249_ec.0197_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0198/HD23249_ec.0198_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0199/HD23249_ec.0199_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251029/HD23249_ec.0071/HD23249_ec.0071_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251029/HD23249_ec.0072/HD23249_ec.0072_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0282/HD23249_ec.0282_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0283/HD23249_ec.0283_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0284/HD23249_ec.0284_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0312/HD23249_ec.0312_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0313/HD23249_ec.0313_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0314/HD23249_ec.0314_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0342/HD23249_ec.0342_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0343/HD23249_ec.0343_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0344/HD23249_ec.0344_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0372/HD23249_ec.0372_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0373/HD23249_ec.0373_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0374/HD23249_ec.0374_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0402/HD23249_ec.0402_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0403/HD23249_ec.0403_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0404/HD23249_ec.0404_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0468/HD23249_ec.0468_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0469/HD23249_ec.0469_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0470/HD23249_ec.0470_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0498/HD23249_ec.0498_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0499/HD23249_ec.0499_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0500/HD23249_ec.0500_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0582/HD23249_ec.0582_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0583/HD23249_ec.0583_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0486/HD23249_ec.0486_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0487/HD23249_ec.0487_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0488/HD23249_ec.0488_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0516/HD23249_ec.0516_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0517/HD23249_ec.0517_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0518/HD23249_ec.0518_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0546/HD23249_ec.0546_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0547/HD23249_ec.0547_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0548/HD23249_ec.0548_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0576/HD23249_ec.0576_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0577/HD23249_ec.0577_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0578/HD23249_ec.0578_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0258/HD23249_ec.0258_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0259/HD23249_ec.0259_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0260/HD23249_ec.0260_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0279/HD23249_ec.0279_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0280/HD23249_ec.0280_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0281/HD23249_ec.0281_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0435/HD23249_ec.0435_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0437/HD23249_ec.0437_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0244/HD23249_ec.0244_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0245/HD23249_ec.0245_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0246/HD23249_ec.0246_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0274/HD23249_ec.0274_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0275/HD23249_ec.0275_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0276/HD23249_ec.0276_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0304/HD23249_ec.0304_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0305/HD23249_ec.0305_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0306/HD23249_ec.0306_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0334/HD23249_ec.0334_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0335/HD23249_ec.0335_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0336/HD23249_ec.0336_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0364/HD23249_ec.0364_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0365/HD23249_ec.0365_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0366/HD23249_ec.0366_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0394/HD23249_ec.0394_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0395/HD23249_ec.0395_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0396/HD23249_ec.0396_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0165/HD23249_ec.0165_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0166/HD23249_ec.0166_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0167/HD23249_ec.0167_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0168/HD23249_ec.0168_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0169/HD23249_ec.0169_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0170/HD23249_ec.0170_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0198/HD23249_ec.0198_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0199/HD23249_ec.0199_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0200/HD23249_ec.0200_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0201/HD23249_ec.0201_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0202/HD23249_ec.0202_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0203/HD23249_ec.0203_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0231/HD23249_ec.0231_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0232/HD23249_ec.0232_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0233/HD23249_ec.0233_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0234/HD23249_ec.0234_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0235/HD23249_ec.0235_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0236/HD23249_ec.0236_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0264/HD23249_ec.0264_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0265/HD23249_ec.0265_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0266/HD23249_ec.0266_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0267/HD23249_ec.0267_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0268/HD23249_ec.0268_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0269/HD23249_ec.0269_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0158/HD23249_ec.0158_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0159/HD23249_ec.0159_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0160/HD23249_ec.0160_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0188/HD23249_ec.0188_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0189/HD23249_ec.0189_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0190/HD23249_ec.0190_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0191/HD23249_ec.0191_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0192/HD23249_ec.0192_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0193/HD23249_ec.0193_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0221/HD23249_ec.0221_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0222/HD23249_ec.0222_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0223/HD23249_ec.0223_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0224/HD23249_ec.0224_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0225/HD23249_ec.0225_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0226/HD23249_ec.0226_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0245/HD23249_ec.0245_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0246/HD23249_ec.0246_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0247/HD23249_ec.0247_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0248/HD23249_ec.0248_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0249/HD23249_ec.0249_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0250/HD23249_ec.0250_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251110/HD23249_ec.0237/HD23249_ec.0237_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251110/HD23249_ec.0240/HD23249_ec.0240_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251111/HD23249_ec.0300/HD23249_ec.0300_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251111/HD23249_ec.0301/HD23249_ec.0301_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251112/HD23249_ec.0261/HD23249_ec.0261_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251112/HD23249_ec.0262/HD23249_ec.0262_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251112/HD23249_ec.0263/HD23249_ec.0263_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0205/HD23249_ec.0205_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0206/HD23249_ec.0206_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0207/HD23249_ec.0207_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0208/HD23249_ec.0208_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0210/HD23249_ec.0210_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251114/HD23249_ec.0247/HD23249_ec.0247_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251114/HD23249_ec.0248/HD23249_ec.0248_res1.h5',
#  '/home/holtz/git/pyodine/apo_data/obs_results/UT251114/HD23249_ec.0249/HD23249_ec.0249_res1.h5']

# %% [markdown]
# Furthermore, to achieve highest precision in the barycentric correction (which is performed by the package [**barycorrpy**](https://github.com/shbhuk/barycorrpy)), we set up a dictionary with supplementary information which will overwrite the information extracted from the modelling results. **barycorrpy** comes with a built-in *Hipparcos*-atlas, which we can use to get reliable coordinates for the star (otherwise telescope coordinates from the original FITS-headers are used, which might be off sometimes). As the star's name in the modelling results (also extracted from the original FITS-headers) is 'HD185144', we will have to pass the corresponding HIP-identifier extra here (commented out you find other possible fields of the dictionary):

# %%
bary_dict = {
    'star_name': 'HIP17378',
    #'star_ra': 0.0,          # in deg
    #'star_dec': 0.0,
    #'star_pmra': 0.0,        # in mas/yr
    #'star_pmdec': 0.0,
    #'star_rv0': 0.0,         # in m/s
    #'instrument_lat': 0.0,   # in deg
    #'instrument_long': 0.0, 
    #'instrument_alt': 0.0    # in m
}

# %% [markdown]
# Finally, we run the velocity combination routine, which loads all the individual model results from file, computes the RV timeseries, performes the barycentric correction, and saves the `CombinedResults` object as well as some analysis plots and additional data as specified above. In the end the `CombinedResults` object is returned:

# %%
Results = pyodine_combine_vels.combine_velocity_results(
    Pars, res_files=res_files, plot_dir=plot_dir, comb_res_out=comb_res_out, 
    vels_out=vels_out, error_log=error_file, info_log=info_file,
    bary_dict=bary_dict)
# Out:
# Branch: master
# Hash: bc51e2c
# ---------------------------
# Weighting and combining velocities
# 100% (130 of 130) |######################| Elapsed Time: 0:00:04 Time:  0:00:040000
# Star: HD23249
#
# Velocity weighting and combination...
# ---------------------------------------------------
# - Pyodine chunk combination (based on iSONG code) -
# ---------------------------------------------------
#
# Weighting parameters used:
# 	good_chunks	None
# 	good_orders	None
# 	sig_limit_low	4.0
# 	sig_limit_up	1000.0
# 	sig_correct	1000.0
# 	reweight_alpha	1.8
# 	reweight_beta	8.0
# 	reweight_sigma	2.0
# 	weight_correct	0.01
#
# Nr. of obs, chunks per obs: 130, 506
#
# Chunk-to-chunk offsets from observation mean:
# Median: -7.78 +- 188.48
#
# Chunk sigmas:
# Median: 136.83 +- 115.99
#
# RV quality factor 1 ( sqrt(1/sum(1/sig**2)) ): 4.88946 m/s
# RV quality factor 2 ( sqrt(1/sum(med(wt1))) ): 4.88946 m/s
#
# Doing the precise barycentric velocity correction...
# Using BVC information from user-supplied dictionary...
# BVC through HIP number: 17378
#
# Writing results to txt file: /home/holtz/git/pyodine/apo_data/vel_results/apo.vels
#
# Saving combined results to /home/holtz/git/pyodine/apo_data/vel_results/apo_comb.h5
#
# Creating and saving analysis plots to:
# 	/home/holtz/git/pyodine/apo_data/vel_results
#
# Observations with outlier RVs:
# /home/holtz/git/pyodine/apo_data/obs_results/UT251112/HD23249_ec.0263/HD23249_ec.0263_res1.h5
# /home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0205/HD23249_ec.0205_res1.h5
# /home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0206/HD23249_ec.0206_res1.h5
# /home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0207/HD23249_ec.0207_res1.h5
# /home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0208/HD23249_ec.0208_res1.h5
# /home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0210/HD23249_ec.0210_res1.h5
# /home/holtz/git/pyodine/apo_data/obs_results/UT251114/HD23249_ec.0247/HD23249_ec.0247_res1.h5
# /home/holtz/git/pyodine/apo_data/obs_results/UT251114/HD23249_ec.0248/HD23249_ec.0248_res1.h5
# /home/holtz/git/pyodine/apo_data/obs_results/UT251114/HD23249_ec.0249/HD23249_ec.0249_res1.h5
#
# All done! Full work time: 21.01339054107666

# %% [markdown]
# Great, and again some print output to explain:
#
# - First up, the weighting parameters used in the velocity combination (and supplied through the `Timeseries_Parameters` object) are printed. Also the code reports about the number of observations and chunks that it found in the results.
#
# - Next, during the velocity combination algorithm, the (robust) mean and standard deviation (std) of the offsets of chunk timeseries from observation means are printed. Below, the mean and std of the velocity scatter within each chunk timeseries is reported ('Chunk sigmas'). The sigmas are used to weight the chunk velocities when computing the RV timeseries.
#
# - Then, two 'quality factors' for the velocity weighting are reported. They should always be very similar, and as they basically represent an average RV precision achieved in this timeseries, you would want them to be as small as possible.
#
# - Finally, the barycentric correction is performed for each observation with the Python package **barycorrpy**. Note that the output informs us about the *precise* correction being used - this corresponds to Equation 10 in [Wright and Eastman (2014)](https://arxiv.org/pdf/1409.4774.pdf), where the *absolute* Doppler shift as measured by the instrument is taken into account in a multiplicative way. As the authors explain, this can make a difference on the m/s-level as compared to a pure sum of *predicted* barycentric velocities with the measured radial velocities.
#
# **Important:** As stated above, *absolute* measured RVs are needed for the precise barycentric correction, however in general the combined RVs in the I2 cell method are first only relative to the template observation, which has an RV offset with respect to laboratory wavelengths itself. Thankfully, in **pyodine**, during the template creation we have computed a template velocity offset with respect to the reference spectrum (which is at laboratory wavelengths), and that template velocity offset $RV_\mathrm{temp}$ is transported all the way through to the modelling results used in the velocity combination. So, we can use it to compute a good estimate of the *absolute* RVs:
#
# $$
#     RV_i^\mathrm{abs} = RV_i + RV_\mathrm{temp}
# $$
#
# In case you ever want to use a different template velocity offset (e.g. you have reason to believe that something went horribly wrong there), you can pass it into the velocity combination routine above as an additional argument `temp_vel=xxx.x` (in m/s). Similarly, if you've used a reference spectrum that is not at laboratory wavelengths, you can pass its velocity offset to the routine as `ref_vel=xxx.x`, and it will also be added to the individual RVs.
#
# **Also Important:** One can also correct the observation times to the barycenter of the Solar System - in **barycorrpy** the corrected dates are called 'BJDTDB'. In **pyodine**, we refer to the original dates extracted from the observation FITS-headers as 'bary_date' (because this is the date when the barycentric correction should be performed), and we call the barycentric corrected dates 'bary_date_corr' (this refers to 'BJDTDB'). Make sure you use the correct one when using the combined velocities (we will use the corrected one below).

# %% [markdown]
# ## Inspect the results

# %% [markdown]
# Now finally, after all this modelling, we can plot our RV timeseries. The barycentric dates, corrected RVs and uncertainties are available as attributes of the `CombinedResults` object called 'Results'.
#
# Note: If you have passed a filepath to the argument `comb_res_out` in the velocity combination above (which we have done here), then this `CombinedResults` object is saved there as HDF5-file. Then, you can simply load it like this:

# %%
# %matplotlib inline

# %%
Results = pyodine.timeseries.base.CombinedResults(os.path.join(plot_dir, 'apo_comb.h5'))
# Out:
# Loading combined results from /home/holtz/git/pyodine/apo_data/vel_results/apo_comb.h5

# %%
# The barycentric date, corrected bary date (shifted to solar system center),
# RV with barycentric correction, and RV uncertainty
bary_date      = Results.bary_date
bary_date_corr = Results.bary_date_corr
rv_bc          = Results.rv_bc
rv_err         = Results.rv_err

star_name = Results.info['star_name']     # the star name

# And plot
fig = plt.figure(figsize=(10,6))
plt.errorbar(bary_date_corr, rv_bc, yerr=rv_err, fmt='o', alpha=0.7,
            label='{:.2f} +- {:.2f} m/s'.format(np.mean(rv_bc), np.std(rv_bc)))
plt.legend()
plt.xlabel('Time [JD]')
plt.ylabel('Velocity [m/s]')
plt.title('{}: RV timeseries'.format(star_name))
plt.show()

# %% [markdown]
# In addition to the RV timeseries, the 'Results' object contains meta-information from the velocity weighting algorithm, that can help us to evaluate the trustworthyness of the results. For example, we can look at the scatter of individual chunk velocities (i.e. the robust standard deviation) for each observation:

# %%
c2c_scatter = Results.c2c_scatter

fig = plt.figure(figsize=(10,6))
plt.plot(bary_date_corr, c2c_scatter, 'o', alpha=0.7,
        label='{:.2f} +- {:.2f} m/s'.format(np.mean(c2c_scatter), np.std(c2c_scatter)))
plt.legend()
plt.xlabel('Time [JD]')
plt.ylabel('Velocity [m/s]')
plt.title('{}: Chunk velocity scatter in observations'.format(star_name))
plt.show()

# %% [markdown]
# Even more: We can plot the chunk sigmas (velocity scatter within each chunk timeseries) over the mean counts of each chunk timeseries. We expect a downward correlation, where chunks with higher counts have smaller sigmas (as they should deliver a better estimate of the true RV in each observation):

# %%
# Extract the median counts (medcnts) of each chunk in each observation, and average them over the observations
medcnts_mean = np.mean(Results.medcnts, axis=0)
# Extract the chunk sigmas
chunk_sigma  = Results.auxiliary['chunk_sigma']

fig = plt.figure(figsize=(10,6))
plt.plot(medcnts_mean, chunk_sigma, '.', alpha=0.7)
plt.xlabel('Mean of chunk fluxes [ADU]')
plt.ylabel('Chunk sigma [m/s]')
plt.ylim(0,200)
plt.title('{}: Chunk sigmas over mean chunk fluxes'.format(star_name))
plt.show()

# %% [markdown]
# The correlation is just there, but so are a lot of outliers - most of which are chunks at redder wavelengths, where tellurics and the fringing effect negatively impact the model.
#
# In addition to the RV timeseries, the velocity weighting algorithm computes the so-called Chromatic Index for each observation - a measure of the slope of Doppler velocity over wavelength. It can be used as an activity indicator, as a varying Chromatic Index can be a sign of stellar spots leading to a RV variation (see e.g. [Reiners +2010](https://ui.adsabs.harvard.edu/abs/2010ApJ...710..432R/abstract) for a physical description, and [Zechmeister +2017](https://ui.adsabs.harvard.edu/abs/2018A%26A...609A..12Z/abstract) for a code implementation and exemplary results).
#
# **Note**: This is still very experimental - it is highly debatable how significant the Chromatic Index results from I2 cell codes are, or probably they only make sense for very high $S/N$-spectra, and we certainly need to test this more!

# %%
crx     = Results.crx
crx_err = Results.crx_err

fig = plt.figure(figsize=(10,6))
plt.errorbar(bary_date_corr, crx, yerr=crx_err, fmt='o', alpha=0.7,
            label='{:.2f} +- {:.2f} (m/s)/Np'.format(np.mean(crx), np.std(crx)))
plt.legend()
plt.xlabel('Time [JD]')
plt.ylabel('Chromatic index [(m/s)/Np]')
plt.title('{}: Chromatix index variation'.format(star_name))
plt.show()

# %% [markdown]
# Looks quite stable! And to give you an idea of what is measured by the Chromatic Index, let's plot the individual chunk velocities for one observation and overplot the fitted Chromatic Index model, which looks like:
#
# $$
#     v_\mathrm{fit} (\lambda) = RV + \beta \ln \frac{\lambda_\mathrm{RV}}{\lambda} \quad ,
# $$
#
# where $RV$ is the weighted RV of the observation, $\beta$ is the Chromatic Index, and $\lambda_\mathrm{RV}$ is the effective wavelength of the weighted RV.

# %%
obs_ind = 2     # observation index

# The chunk wavelength intercepts of the observation
wave_int     = Results.params['wave_intercept'][obs_ind]
# The chunk velocities of the observation
velocity     = Results.params['velocity'][obs_ind]
# The weighted RV of the observation
rv_obs       = Results.rv[obs_ind]
# The CRX model effective wavelength of the RV (and error)
RV_wave      = Results.RV_wave[obs_ind]
RV_wave_err  = Results.RV_wave_err[obs_ind]
# The CRX model chromatic index (and error)
crx_obs      = Results.crx[obs_ind]
crx_obs_err  = Results.crx_err[obs_ind]

# Compute the velocities from the CRX model, along with upper and lower uncertainty
velocities_fit = pyodine.timeseries.combine_vels.velocity_from_chromatic_index(
    wave_int, rv_obs, RV_wave, crx_obs)
velocities_fit_lower = pyodine.timeseries.combine_vels.velocity_from_chromatic_index(
    wave_int, rv_obs-rv_err[obs_ind], RV_wave-RV_wave_err, crx_obs-crx_obs_err)
velocities_fit_upper = pyodine.timeseries.combine_vels.velocity_from_chromatic_index(
    wave_int, rv_obs+rv_err[obs_ind], RV_wave+RV_wave_err, crx_obs+crx_obs_err)

fig = plt.figure(figsize=(10,6))
plt.plot(wave_int, velocity, '.', alpha=0.7, label='Chunk velocities')
plt.plot(wave_int, velocities_fit, alpha=0.7, label='CRX model\n' + 
         r'$\beta={:.1f}\pm{:.1f}$ (m/s)/Np'.format(crx_obs, crx_obs_err))
plt.plot(wave_int, velocities_fit_lower, 'k', alpha=0.3)
plt.plot(wave_int, velocities_fit_upper, 'k', alpha=0.3)
plt.legend()
plt.xlabel(r'Wavelength [$\AA$]')
plt.ylabel('Chunk velocities [m/s]')
plt.ylim(400., 1600.)
plt.title('{}, observation {}: Chunk velocities and CRX model'.format(star_name, obs_ind))
plt.show()

# %% [markdown]
# Finally, here is an overview of the most important `CombinedResults` properties and variables:
#
# | Parameter | Description |
# | :- | :- |
# | Results.params        | fit results of model parameters from all observations and chunks  |
# | Results.errors        | fit errors of model parameters                                    |
# | Results.orig_filename | list of observation filenames                                     |
# | Results.res_filename  | list of model results filenames                                   |
# | Results.chunks        | dictionary with information about chunks in all observations      |
# | Results.redchi2       | red. $\chi^2$ of the fits in all observations/chunks              |
# | Results.residuals     | relative residuals between model and observation in all observations/chunks |
# | Results.medcnts       | median counts of all chunks in all observations                   |
# | Results.info          | dictionary with general info (instrument, star, model used,...)   |
# | Results.timeseries    | dictionary with timeseries parameters (these are directly accessible as properties) |
# | Results.auxiliary     | dictionary with additional info from velocity combination (e.g. weights) |

# %%
Results.timeseries
# Out:
# {'RV_wave': array([5053.7610945 , 5053.75891983, 5053.75634704, 5053.76222799,
#         5053.75616944, 5053.75829732, 5053.76009167, 5053.79124209,
#         5053.78379238, 5053.80435805, 5053.80999053, 5053.8085661 ,
#         5053.80767028, 5053.8098122 , 5053.80842745, 5053.80508229,
#         5053.80377734, 5053.80391504, 5053.80169578, 6208.14701595,
#         5053.80399829, 5053.80413547, 5053.79866887, 5053.79803567,
#         5053.8060371 , 6208.16251399, 5053.80786628, 5053.80579118,
#         5053.79990553, 5053.80149689, 5053.81607973, 5053.81249912,
#         6208.15831611, 6208.16487535, 5053.81088968, 5053.81654475,
#         6208.16304103, 6208.16810694, 6208.16731171, 6208.16458939,
#         5053.8160743 , 5053.81520088, 5053.81256962, 5053.81659633,
#         5053.81153892, 5053.81417062, 5053.8049408 , 6208.16724665,
#         6208.15816794, 5053.80967563, 5053.80442414, 6208.16055277,
#         6208.1887941 , 6208.18644518, 6208.1871564 , 5053.83880556,
#         6208.17975422, 6208.18277835, 5053.83196256, 5053.83328437,
#         5053.832592  , 5053.83984248, 5053.82929922, 6208.18688778,
#         6208.18495056, 6208.19545794, 6208.1927372 , 6208.19594616,
#         6208.19367408, 6208.20047992, 5053.83635883, 6208.2069626 ,
#         5053.83924876, 5053.84345522, 6208.2051887 , 6208.19556508,
#         5053.83949924, 5053.83947147, 5053.8360639 , 6208.19843103,
#         5053.83926472, 5053.83545607, 5053.83557961, 5053.83878188,
#         5053.83760963, 6208.19776513, 5053.83575792, 6208.19463081,
#         5053.83508946, 6208.19469054, 5053.83259313, 5053.84425653,
#         6208.19098585, 6208.19343301, 5053.82896269, 6208.17479703,
#         5053.83383364, 5053.83021969, 5053.82823836, 5053.8361625 ,
#         5053.83050886, 5053.8331353 , 5053.83013668, 6208.19155506,
#         5053.83145142, 5053.83503146, 5053.83159431, 5053.83250934,
#         5053.82824012, 5053.82797465, 6208.19515636, 5053.8307041 ,
#         5053.83011061, 5053.8329733 , 6208.18948631, 5053.887489  ,
#         6208.25380574, 5053.88963537, 5191.58137358, 6208.24167757,
#         6208.25442017, 6208.25456004, 5443.69477812, 5053.899447  ,
#         6208.29817076, 6208.30442872, 5325.42217624, 6208.26140899,
#         5256.77865948, 6114.7659201 ]),
#  'RV_wave_err': array([1.41809846e+00, 1.26108978e+02, 4.42577526e+02, 8.62127015e+01,
#         2.27492231e+02, 1.54384355e+02, 1.28302931e+02, 4.08264194e+02,
#         1.92403763e+02, 4.98375285e+01, 4.25321246e+01, 7.44455202e-01,
#         1.31847968e+03, 3.07116319e+02, 2.28086311e+00, 2.20831036e+02,
#         2.99496691e+02, 7.34025004e+03, 1.35289655e+02, 1.21602961e+02,
#         8.71163365e-01, 5.30995756e+01, 7.37906926e+01, 9.71859792e+00,
#         8.84568408e+01, 2.09643194e+00, 5.06752195e-01, 1.81029347e+02,
#         3.95006467e+00, 3.02913788e+01, 6.01832791e+01, 1.12808811e+02,
#         2.05449057e+02, 3.23793520e+03, 1.66640891e+02, 5.96627482e+01,
#         8.49849346e+01, 6.83557826e+01, 3.51120781e+02, 3.85417268e+04,
#         9.56976282e-01, 3.47000443e-01, 5.54047361e+00, 1.34882573e+02,
#         1.82471277e+02, 1.29313687e+02, 1.03753347e+02, 1.09026900e+01,
#         6.83088125e+01, 4.48059850e+00, 7.34984325e-01, 3.43034488e+01,
#         3.71777895e+02, 5.18721509e+01, 2.72672643e+03, 9.19427246e+01,
#         1.09553712e+03, 7.37417400e+02, 4.54458545e+00, 8.98605063e+01,
#         4.96829500e+02, 1.50029646e+00, 7.72153259e+01, 1.60025083e+03,
#         1.67811280e+02, 3.58180040e+03, 5.15097316e+02, 4.47344264e+02,
#         1.58178584e+02, 7.03806557e+02, 3.08871806e+02, 1.32882200e+03,
#         1.94464907e+01, 1.53477554e+02, 8.42606747e+01, 3.93332402e+02,
#         8.43055209e+01, 6.97992003e+00, 6.39373538e-01, 4.36739266e+02,
#         1.88766612e+00, 3.29136254e+02, 2.92915221e+00, 7.86856521e+01,
#         1.12744327e+00, 9.28411654e+02, 7.93159790e+01, 2.55482715e+02,
#         1.03221108e+02, 2.06598049e+02, 4.24340278e+01, 3.51502817e+01,
#         1.76743419e+02, 3.23720571e+02, 2.22681166e+01, 5.07086016e+00,
#         9.52916210e+01, 4.06919344e+01, 7.06750761e+01, 1.86935934e+02,
#         4.67005596e+01, 6.77539812e+01, 2.52490477e+02, 4.06380897e+02,
#         1.16078934e+02, 1.89653387e+02, 7.96620633e+01, 1.33106604e+02,
#         1.32600585e+02, 1.35872324e+00, 3.12321280e+03, 3.45723718e+00,
#         3.53856934e+01, 7.07112229e+01, 2.75093259e+02, 1.08955866e+02,
#         2.23752400e+02, 9.59222547e+01, 6.04523544e+01, 6.61689811e+02,
#         4.41005092e+02, 5.82554117e+03, 2.69970282e+02, 1.78864842e+01,
#         8.13452595e+02, 1.02042253e+03, 6.30762320e+01, 1.01214937e+02,
#         6.21876988e+01, 7.62485174e+02]),
#  'bary_date': array([2460973.89456004, 2460973.90521819, 2460973.91585181,
#         2460973.92948655, 2460973.96479593, 2460973.97544866,
#         2460973.9860672 , 2460977.77896282, 2460977.78613794,
#         2460978.75914638, 2460978.76625862, 2460978.77339388,
#         2460978.78625251, 2460978.79337782, 2460978.80052222,
#         2460978.81335984, 2460978.82049323, 2460978.82764502,
#         2460978.84050382, 2460978.8476098 , 2460978.85473364,
#         2460978.86762037, 2460978.87476931, 2460978.88188349,
#         2460978.90091889, 2460978.90802052, 2460978.91521142,
#         2460978.92821704, 2460978.93535103, 2460978.9424719 ,
#         2460978.96463581, 2460978.9717542 , 2460979.85837525,
#         2460979.86552759, 2460979.87268191, 2460979.8857077 ,
#         2460979.89281108, 2460979.89992742, 2460979.91334248,
#         2460979.92048099, 2460979.92761865, 2460979.94060323,
#         2460979.94771541, 2460979.95484019, 2460980.77175741,
#         2460980.77888322, 2460980.78602699, 2460980.79772396,
#         2460980.80484426, 2460980.81195106, 2460980.91569327,
#         2460980.92997879, 2460981.79620486, 2460981.80331277,
#         2460981.81045245, 2460981.82464613, 2460981.83178905,
#         2460981.83891975, 2460981.85298273, 2460981.86010737,
#         2460981.86721838, 2460981.88138711, 2460981.88851279,
#         2460981.89566828, 2460981.90939786, 2460981.91651514,
#         2460981.92363306, 2460981.93746207, 2460981.94460744,
#         2460981.95175085, 2460982.75125238, 2460982.75839265,
#         2460982.76549462, 2460982.77291582, 2460982.78001953,
#         2460982.78716444, 2460982.80114242, 2460982.80831178,
#         2460982.81543385, 2460982.82284491, 2460982.82999925,
#         2460982.83710626, 2460982.8511483 , 2460982.85828287,
#         2460982.86541011, 2460982.87280833, 2460982.87996064,
#         2460982.88708797, 2460982.90103996, 2460982.90821936,
#         2460982.91535096, 2460982.92278255, 2460982.92989187,
#         2460982.93702607, 2460983.78155877, 2460983.78867521,
#         2460983.79581564, 2460983.80989926, 2460983.81705074,
#         2460983.82419456, 2460983.83162525, 2460983.83876207,
#         2460983.84589633, 2460983.86615556, 2460983.87326502,
#         2460983.88036821, 2460983.88776444, 2460983.89489918,
#         2460983.90207032, 2460983.91466167, 2460983.92181707,
#         2460983.92893394, 2460983.93634266, 2460983.9434856 ,
#         2460983.95062542, 2460989.71673601, 2460989.72808321,
#         2460990.72462577, 2460990.72828726, 2460991.71784824,
#         2460991.72148199, 2460991.72513514, 2460992.70146731,
#         2460992.70509564, 2460992.70875903, 2460992.71275567,
#         2460992.72006814, 2460993.70903556, 2460993.71270475,
#         2460993.71642774]),
#  'bary_date_corr': array([2460973.90009223, 2460973.91075067, 2460973.92138457,
#         2460973.93501968, 2460973.97032999, 2460973.98098301,
#         2460973.99160182, 2460977.78458986, 2460977.79176514,
#         2460978.76479386, 2460978.77190624, 2460978.77904165,
#         2460978.79190054, 2460978.79902599, 2460978.80617054,
#         2460978.81900843, 2460978.82614196, 2460978.8332939 ,
#         2460978.84615296, 2460978.85325908, 2460978.86038306,
#         2460978.87327005, 2460978.88041913, 2460978.88753344,
#         2460978.90656922, 2460978.91367098, 2460978.92086202,
#         2460978.93386789, 2460978.94100202, 2460978.94812303,
#         2460978.97028736, 2460978.97740589, 2460979.86404399,
#         2460979.87119646, 2460979.87835091, 2460979.89137694,
#         2460979.89848045, 2460979.90559692, 2460979.91901221,
#         2460979.92615085, 2460979.93328864, 2460979.94627345,
#         2460979.95338575, 2460979.96051066, 2460980.77744243,
#         2460980.78456837, 2460980.79171226, 2460980.80340944,
#         2460980.81052986, 2460980.81763678, 2460980.92138073,
#         2460980.93566649, 2460981.80190669, 2460981.80901471,
#         2460981.8161545 , 2460981.8303484 , 2460981.83749144,
#         2460981.84462225, 2460981.85868545, 2460981.8658102 ,
#         2460981.87292132, 2460981.88709026, 2460981.89421605,
#         2460981.90137164, 2460981.91510143, 2460981.92221882,
#         2460981.92933684, 2460981.94316606, 2460981.95031153,
#         2460981.95745504, 2460982.75696844, 2460982.76410881,
#         2460982.77121089, 2460982.7786322 , 2460982.78573602,
#         2460982.79288103, 2460982.80685921, 2460982.81402867,
#         2460982.82115085, 2460982.82856201, 2460982.83571645,
#         2460982.84282356, 2460982.85686579, 2460982.86400046,
#         2460982.8711278 , 2460982.87852613, 2460982.88567853,
#         2460982.89280596, 2460982.90675814, 2460982.91393763,
#         2460982.92106933, 2460982.92850102, 2460982.93561043,
#         2460982.94274472, 2460983.7872887 , 2460983.79440522,
#         2460983.80154575, 2460983.81562955, 2460983.82278112,
#         2460983.82992503, 2460983.83735582, 2460983.84449272,
#         2460983.85162708, 2460983.87188655, 2460983.8789961 ,
#         2460983.88609938, 2460983.89349569, 2460983.90063053,
#         2460983.90780174, 2460983.92039325, 2460983.92754873,
#         2460983.93466569, 2460983.94207449, 2460983.94921752,
#         2460983.95635741, 2460989.7225146 , 2460989.73386184,
#         2460990.73040733, 2460990.73406883, 2460991.7236312 ,
#         2460991.72726496, 2460991.73091812, 2460992.70725017,
#         2460992.71087849, 2460992.71454188, 2460992.71853852,
#         2460992.725851  , 2460993.71481679, 2460993.71848598,
#         2460993.72220896]),
#  'bary_vel_corr': array([8071.42352323, 8041.91535915, 8013.00890441, 7976.9008049 ,
#         7889.86265844, 7865.83011819, 7843.06109082, 6625.33737485,
#         6606.0411292 , 6229.77003034, 6211.43226726, 6192.67834364,
#         6158.08029265, 6138.52222065, 6118.6773636 , 6082.53567433,
#         6062.24588307, 6041.79889373, 6004.88335811, 5984.46120316,
#         5964.01618006, 5927.21624905, 5906.96613645, 5886.97435748,
#         5834.52715717, 5815.4443416 , 5796.44046764, 5762.98920995,
#         5745.19840581, 5727.8723308 , 5677.01359246, 5661.75778403,
#         5503.78514658, 5483.3973721 , 5463.13366534, 5426.68761817,
#         5407.11622951, 5387.76687318, 5352.1057558 , 5333.62316665,
#         5315.52558579, 5283.6833317 , 5266.88458993, 5250.54716519,
#         5297.29017903, 5278.05361894, 5258.49200001, 5225.95136318,
#         5205.88625533, 5185.70653184, 4895.37857491, 4859.31642723,
#         4777.87023376, 4757.80285945, 4737.49805403, 4696.82863333,
#         4676.27891569, 4655.75531595, 4615.38851253, 4595.06177229,
#         4574.90267081, 4535.25422979, 4515.64235792, 4496.21413945,
#         4459.80069045, 4441.43224838, 4423.4495616 , 4389.73001912,
#         4372.9929801 , 4356.76391639, 4446.403143  , 4427.79847282,
#         4408.95205559, 4388.92813533, 4369.47831486, 4349.66997673,
#         4310.33413494, 4289.92600077, 4269.54198778, 4248.25109621,
#         4227.65707651, 4207.1948061 , 4166.88759445, 4146.53871953,
#         4126.34446772, 4105.56054473, 4085.67525402, 4066.09643491,
#         4028.58160974, 4009.75938813, 3991.42837251, 3972.74723037,
#         3955.30912706, 3938.2646658 , 3910.67336138, 3890.80555968,
#         3870.67906711, 3830.55135042, 3810.02474635, 3789.46554321,
#         3768.06041651, 3747.51880536, 3727.03671681, 3669.46362863,
#         3649.5728268 , 3629.91663668, 3609.715391  , 3590.51912357,
#         3571.54585073, 3539.10695454, 3521.22300275, 3503.868418  ,
#         3486.29117759, 3469.84607623, 3453.92700228, 1330.61834172,
#         1302.10506251,  848.1090589 ,  838.7066477 ,  401.43814018,
#          392.21822449,  382.84522076,  -22.75954455,  -31.54720813,
#          -40.53876592,  -50.48006411,  -69.00850763, -506.57564648,
#         -515.79175669, -525.25407382]),
#  'c2c_scatter': array([ 223.73129234,  224.83900242,  230.24471612,  226.83823448,
#          203.30207803,  215.85416365,  258.18639639,  186.4468456 ,
#          249.82511636,  170.84295075,  158.92700016,  155.02668402,
#          152.99602698,  158.11112687,  162.18802835,  161.90363282,
#          156.4170178 ,  158.99034093,  153.25969572,  150.78983951,
#          152.54016076,  140.22541224,  154.60646204,  161.69241024,
#          165.27535451,  158.37904671,  161.69181257,  156.30735168,
#          159.84349125,  136.11718084,  192.58750769,  218.92978321,
#          143.14890421,  141.39618403,  143.88311527,  146.57879003,
#          136.00691534,  133.39189559,  158.29079865,  145.97932945,
#          145.70905008,  165.27481316,  148.66946082,  168.60956505,
#          176.55884488,  173.89576651,  177.29730105,  187.63099978,
#          183.29378613,  184.76400495,  225.60910923,  226.67119691,
#          152.30519665,  122.08160311,  133.34746122,  134.59264175,
#          118.18248309,  130.82310353,  128.35999594,  128.94019641,
#          150.31350619,  153.37020157,  136.5942782 ,  150.39863636,
#          167.07081927,  182.37712595,  186.61778349,  164.32185093,
#          191.86589914,  185.20246333,  164.13523526,  166.02384115,
#          157.6633419 ,  140.76209678,  147.40976274,  147.19740137,
#          143.85010261,  179.03186462,  227.2985456 ,  185.84391226,
#          175.60474754,  147.13480191,  159.65194821,  170.47086072,
#          183.06951749,  161.15231252,  126.75070335,  132.87946697,
#          185.85469797,  154.21157144,  170.33402858,  168.16108621,
#          192.22430672,  203.68757952,  155.099254  ,  146.11504311,
#          147.41092071,  138.82049421,  152.63339841,  143.16981141,
#          127.65849467,  135.67471496,  163.57676301,  163.81421256,
#          183.86330761,  159.0667988 ,  152.40387767,  170.74651807,
#          169.52510426,  211.95717669,  184.97015172,  187.38230622,
#          211.41519917,  205.36185093,  230.95456287,  282.44273445,
#          274.15547051,  317.46077482,  303.46293556,  298.54150584,
#          351.32234739,  327.35914441, 1140.34804312, 1155.94173406,
#         1128.55809113, 1093.51356197, 1209.32233252, 1172.60700183,
#         1211.75395598, 1266.91525699]),
#  'crx': array([ 248.90763132,  328.13861526,  284.18834558,  267.67878655,
#          282.70846371,  299.18508971,  336.25342173,  253.17514775,
#          285.14789192,  310.22224554,  288.73861395,  294.35474945,
#          265.36289167,  273.38869408,  304.58947602,  330.03646755,
#          313.67690142,  278.75837862,  275.29868705, -166.78822296,
#          321.38638332,  339.04666893,  348.51151359,  346.48402966,
#          367.62336374, -186.97718266,  366.61135498,  309.69885586,
#          299.71688232,  315.70420265,  341.2353034 ,  406.12283898,
#         -195.77704325, -205.19253105,  348.83945055,  329.207462  ,
#         -193.2699928 , -195.78419352, -222.7702028 , -212.12804476,
#          414.14194781,  387.06432968,  378.92423712,  345.37704663,
#          382.42501458,  414.51185742,  408.32221383, -231.79893941,
#         -197.4214017 ,  361.01752331,  340.05647142, -231.59095622,
#         -241.52571883, -243.69195859, -223.43657041,  376.45629837,
#         -174.62912572, -202.37077601,  340.25121188,  391.0512379 ,
#          383.61682329,  356.66181515,  372.87288452, -209.34149202,
#         -241.32512307, -213.88524623, -232.53735948, -215.50647721,
#         -227.48001504, -245.19416545,  401.42415766, -220.72265669,
#          414.55951226,  353.38165242, -203.69635705, -199.31123668,
#          300.20398109,  376.94595141,  378.39678642, -193.97580264,
#          462.22072532,  395.04365626,  352.30311075,  352.69106206,
#          384.48992366, -212.25936847,  327.06590791, -205.85224291,
#          380.84296014, -211.59950938,  289.15483442,  311.9484764 ,
#         -212.2097301 , -216.88671706,  317.0304981 , -206.35447385,
#          309.6148318 ,  265.58645964,  280.03046167,  286.13835952,
#          296.37502958,  339.30651897,  329.93687843, -232.67624429,
#          340.96452977,  353.88769377,  347.19037531,  330.5371665 ,
#          288.70295303,  325.71591636, -224.96743187,  297.3316371 ,
#          368.77272453,  387.15908033, -258.92829441,  376.70817515,
#         -168.26273911,  439.72696236,  619.10961761, -135.2833454 ,
#         -201.27409888, -171.781287  ,  122.79661729,   41.91210447,
#         -107.36190965, -162.82564076,  543.07129282,  -82.54306951,
#          548.17748088,  163.09012686]),
#  'crx_err': array([ 91.82290981,  98.88989246,  97.21691043, 101.03341558,
#          92.86953122,  98.5013571 , 104.59157673, 100.19969573,
#         114.30573629,  90.34117632,  87.73817342,  86.97962008,
#          86.08077594,  86.60392696,  88.12855212,  93.97491285,
#          86.83904337,  85.98765802,  89.3565965 ,  84.94556264,
#          92.75747592,  88.94111737,  90.09347367,  91.28792445,
#          89.14338274,  90.17381292,  91.28773434,  90.67826391,
#          88.61763862,  91.45526272, 100.71528158, 103.03518608,
#          79.68313972,  85.48738493,  84.47331145,  93.31170587,
#          88.18823094,  81.96549388,  88.94511754,  85.13181067,
#          90.99162343,  97.54528712,  94.11693048,  94.34450406,
#         100.23490171,  99.53508249,  94.16282449, 110.14525148,
#         106.59182542, 105.26239346, 106.44813559, 116.11706606,
#          92.17814758,  87.13079071,  86.38427057,  85.01721998,
#          82.03141944,  78.43780657,  82.56781253,  86.9362843 ,
#          95.0606442 ,  92.44558889,  85.68792917,  88.17251948,
#          93.05584515,  95.62485374, 104.35085534,  97.08232135,
#         104.22276404, 102.3462651 ,  94.06304404,  96.87907297,
#          96.33696236,  89.45241675,  89.78562847,  89.45328677,
#          93.31383678,  99.51032537, 113.01425473, 100.90218429,
#         100.4071829 ,  97.36732264,  94.43812274,  89.44933457,
#          96.84279193, 100.67149629,  83.59852963,  93.1875912 ,
#         102.62413939,  97.76669078,  94.73314258,  99.69707435,
#         104.67865865, 107.58711907,  89.16495147,  85.55289309,
#          85.73687238,  90.50881116,  84.86283392,  86.93848685,
#          82.89387741,  83.06319318,  87.10950764,  87.88656144,
#          98.35477024,  93.33938499,  90.2643568 ,  85.6306491 ,
#          94.73245581, 105.30515106, 101.09643237,  97.70706363,
#         102.37746163, 109.62595001, 114.35528252, 109.95039085,
#         114.54394556, 113.48406077, 117.4521124 , 112.41480775,
#         119.63197707, 117.28626741, 162.74021465, 167.84174281,
#         162.29268076, 180.30153545, 178.87035553, 172.1021009 ,
#         152.69387795, 162.12664409]),
#  'crx_redchi': array([1.05226314e-04, 1.21626240e-04, 1.18398914e-04, 1.27548026e-04,
#         1.08728726e-04, 1.21248733e-04, 1.34595257e-04, 1.26438404e-04,
#         1.59560886e-04, 1.03307569e-04, 9.72006523e-05, 9.55018568e-05,
#         9.39158770e-05, 9.51398516e-05, 9.81433780e-05, 1.11929129e-04,
#         9.56658665e-05, 9.37980271e-05, 1.00405081e-04, 9.14992926e-05,
#         1.09056380e-04, 1.00366000e-04, 1.02992117e-04, 1.05441846e-04,
#         1.00740693e-04, 1.03114567e-04, 1.05691621e-04, 1.04206069e-04,
#         9.95905657e-05, 1.06094832e-04, 1.28509252e-04, 1.32249623e-04,
#         8.05687000e-05, 9.26783560e-05, 9.05247267e-05, 1.10485968e-04,
#         9.84167168e-05, 8.52483682e-05, 1.00375136e-04, 9.19592704e-05,
#         1.04950686e-04, 1.20612961e-04, 1.12355294e-04, 1.12838294e-04,
#         1.27246439e-04, 1.25482339e-04, 1.12244104e-04, 1.52541000e-04,
#         1.43730632e-04, 1.40061660e-04, 1.41708082e-04, 1.67542050e-04,
#         1.07626745e-04, 9.62341530e-05, 9.45346477e-05, 9.16868199e-05,
#         8.53439692e-05, 7.77815261e-05, 8.64143666e-05, 9.58730957e-05,
#         1.14411075e-04, 1.08378795e-04, 9.31599277e-05, 9.86218788e-05,
#         1.09857848e-04, 1.15929041e-04, 1.38081014e-04, 1.19483778e-04,
#         1.36594440e-04, 1.31905514e-04, 1.12044553e-04, 1.18809265e-04,
#         1.17361951e-04, 1.01249716e-04, 1.02268808e-04, 1.01485949e-04,
#         1.09938852e-04, 1.25407886e-04, 1.60109364e-04, 1.29031753e-04,
#         1.27279931e-04, 1.20153827e-04, 1.13106597e-04, 1.01137474e-04,
#         1.18881734e-04, 1.28475910e-04, 8.84846730e-05, 1.10111715e-04,
#         1.33171199e-04, 1.21100120e-04, 1.13237047e-04, 1.24628576e-04,
#         1.37639714e-04, 1.44513495e-04, 1.00859742e-04, 9.28196589e-05,
#         9.32278661e-05, 1.03910139e-04, 9.13150164e-05, 9.58507631e-05,
#         8.71911896e-05, 8.74992409e-05, 9.61647948e-05, 9.79742202e-05,
#         1.22560025e-04, 1.10392017e-04, 1.03328258e-04, 9.27961749e-05,
#         1.13655114e-04, 1.39928679e-04, 1.28833969e-04, 1.20857758e-04,
#         1.31913536e-04, 1.51752211e-04, 1.64292007e-04, 1.44433519e-04,
#         1.56368357e-04, 1.50294945e-04, 1.61957325e-04, 1.45315932e-04,
#         1.54687356e-04, 1.57870441e-04, 9.58211637e-05, 1.28846823e-04,
#         1.13538429e-04, 1.27365682e-04, 1.00911078e-04, 1.17005618e-04,
#         8.44051643e-05, 1.10223179e-04]),
#  'mdvel': array([ -58.41073929,  -21.15371734,  -12.57374499,   38.97884436,
#          126.25246454,  141.85241014,  158.07573302, 1375.84642502,
#         1379.70792576, 1766.79241635, 1783.53263072, 1805.82094236,
#         1833.98212041, 1851.35388415, 1873.27312136, 1898.99204949,
#         1926.80404329, 1946.38735162, 1986.60173155, 2003.96313134,
#         2026.40246922, 2053.96842186, 2080.64272282, 2091.20896935,
#         2149.31311797, 2176.08850492, 2191.18995748, 2223.86084683,
#         2231.43808205, 2257.80522113, 2293.67206241, 2301.9734284 ,
#         2473.88859079, 2506.06959284, 2511.20790766, 2557.5433761 ,
#         2570.59041581, 2596.50306609, 2623.65917218, 2648.73112615,
#         2662.62536691, 2696.80506427, 2719.35537522, 2728.78216094,
#         2670.1538157 , 2700.5034299 , 2719.09158402, 2742.726735  ,
#         2780.95303474, 2797.2723201 , 3101.30656575, 3134.30951034,
#         3182.60856871, 3215.48012378, 3235.65138788, 3268.46408653,
#         3299.43483984, 3322.36086386, 3359.48465802, 3381.27773122,
#         3392.97774661, 3443.27155783, 3453.33968079, 3479.34023263,
#         3520.74240932, 3522.22527635, 3539.29536025, 3578.19965349,
#         3602.05599229, 3616.82344363, 3525.72402918, 3537.02151737,
#         3562.52795287, 3584.20349422, 3609.14802431, 3627.26148945,
#         3666.70195598, 3675.40240243, 3693.38992328, 3718.68817873,
#         3738.62144369, 3775.51083309, 3810.918268  , 3836.98246296,
#         3856.87799955, 3874.61494033, 3902.88196677, 3911.595936  ,
#         3947.68617611, 3973.99556723, 3998.19522232, 4011.5958543 ,
#         4029.02378803, 4041.94559437, 4100.54378933, 4103.45163931,
#         4133.88825042, 4169.66603002, 4189.52368037, 4217.02599549,
#         4224.89594318, 4251.85134149, 4275.37798867, 4335.09643466,
#         4346.79825178, 4376.43129353, 4396.81086711, 4416.56134558,
#         4435.23461195, 4476.50340778, 4479.27278204, 4512.47242559,
#         4505.76153109, 4531.67039542, 4546.32336767, 6680.47064782,
#         6725.45886581, 7175.58174013, 7166.56688175, 7601.44142956,
#         7615.43697162, 7640.52570401, 7875.84888761, 7872.31027655,
#         7888.22758294, 7958.12676715, 7878.04166334, 8365.65047979,
#         8362.93992866, 8337.93403349]),
#  'orig_filename': ['HD23249_ec.0173.fits',
#   'HD23249_ec.0174.fits',
#   'HD23249_ec.0175.fits',
#   'HD23249_ec.0185.fits',
#   'HD23249_ec.0197.fits',
#   'HD23249_ec.0198.fits',
#   'HD23249_ec.0199.fits',
#   'HD23249_ec.0071.fits',
#   'HD23249_ec.0072.fits',
#   'HD23249_ec.0282.fits',
#   'HD23249_ec.0283.fits',
#   'HD23249_ec.0284.fits',
#   'HD23249_ec.0312.fits',
#   'HD23249_ec.0313.fits',
#   'HD23249_ec.0314.fits',
#   'HD23249_ec.0342.fits',
#   'HD23249_ec.0343.fits',
#   'HD23249_ec.0344.fits',
#   'HD23249_ec.0372.fits',
#   'HD23249_ec.0373.fits',
#   'HD23249_ec.0374.fits',
#   'HD23249_ec.0402.fits',
#   'HD23249_ec.0403.fits',
#   'HD23249_ec.0404.fits',
#   'HD23249_ec.0468.fits',
#   'HD23249_ec.0469.fits',
#   'HD23249_ec.0470.fits',
#   'HD23249_ec.0498.fits',
#   'HD23249_ec.0499.fits',
#   'HD23249_ec.0500.fits',
#   'HD23249_ec.0582.fits',
#   'HD23249_ec.0583.fits',
#   'HD23249_ec.0486.fits',
#   'HD23249_ec.0487.fits',
#   'HD23249_ec.0488.fits',
#   'HD23249_ec.0516.fits',
#   'HD23249_ec.0517.fits',
#   'HD23249_ec.0518.fits',
#   'HD23249_ec.0546.fits',
#   'HD23249_ec.0547.fits',
#   'HD23249_ec.0548.fits',
#   'HD23249_ec.0576.fits',
#   'HD23249_ec.0577.fits',
#   'HD23249_ec.0578.fits',
#   'HD23249_ec.0258.fits',
#   'HD23249_ec.0259.fits',
#   'HD23249_ec.0260.fits',
#   'HD23249_ec.0279.fits',
#   'HD23249_ec.0280.fits',
#   'HD23249_ec.0281.fits',
#   'HD23249_ec.0435.fits',
#   'HD23249_ec.0437.fits',
#   'HD23249_ec.0244.fits',
#   'HD23249_ec.0245.fits',
#   'HD23249_ec.0246.fits',
#   'HD23249_ec.0274.fits',
#   'HD23249_ec.0275.fits',
#   'HD23249_ec.0276.fits',
#   'HD23249_ec.0304.fits',
#   'HD23249_ec.0305.fits',
#   'HD23249_ec.0306.fits',
#   'HD23249_ec.0334.fits',
#   'HD23249_ec.0335.fits',
#   'HD23249_ec.0336.fits',
#   'HD23249_ec.0364.fits',
#   'HD23249_ec.0365.fits',
#   'HD23249_ec.0366.fits',
#   'HD23249_ec.0394.fits',
#   'HD23249_ec.0395.fits',
#   'HD23249_ec.0396.fits',
#   'HD23249_ec.0165.fits',
#   'HD23249_ec.0166.fits',
#   'HD23249_ec.0167.fits',
#   'HD23249_ec.0168.fits',
#   'HD23249_ec.0169.fits',
#   'HD23249_ec.0170.fits',
#   'HD23249_ec.0198.fits',
#   'HD23249_ec.0199.fits',
#   'HD23249_ec.0200.fits',
#   'HD23249_ec.0201.fits',
#   'HD23249_ec.0202.fits',
#   'HD23249_ec.0203.fits',
#   'HD23249_ec.0231.fits',
#   'HD23249_ec.0232.fits',
#   'HD23249_ec.0233.fits',
#   'HD23249_ec.0234.fits',
#   'HD23249_ec.0235.fits',
#   'HD23249_ec.0236.fits',
#   'HD23249_ec.0264.fits',
#   'HD23249_ec.0265.fits',
#   'HD23249_ec.0266.fits',
#   'HD23249_ec.0267.fits',
#   'HD23249_ec.0268.fits',
#   'HD23249_ec.0269.fits',
#   'HD23249_ec.0158.fits',
#   'HD23249_ec.0159.fits',
#   'HD23249_ec.0160.fits',
#   'HD23249_ec.0188.fits',
#   'HD23249_ec.0189.fits',
#   'HD23249_ec.0190.fits',
#   'HD23249_ec.0191.fits',
#   'HD23249_ec.0192.fits',
#   'HD23249_ec.0193.fits',
#   'HD23249_ec.0221.fits',
#   'HD23249_ec.0222.fits',
#   'HD23249_ec.0223.fits',
#   'HD23249_ec.0224.fits',
#   'HD23249_ec.0225.fits',
#   'HD23249_ec.0226.fits',
#   'HD23249_ec.0245.fits',
#   'HD23249_ec.0246.fits',
#   'HD23249_ec.0247.fits',
#   'HD23249_ec.0248.fits',
#   'HD23249_ec.0249.fits',
#   'HD23249_ec.0250.fits',
#   'HD23249_ec.0237.fits',
#   'HD23249_ec.0240.fits',
#   'HD23249_ec.0300.fits',
#   'HD23249_ec.0301.fits',
#   'HD23249_ec.0261.fits',
#   'HD23249_ec.0262.fits',
#   'HD23249_ec.0263.fits',
#   'HD23249_ec.0205.fits',
#   'HD23249_ec.0206.fits',
#   'HD23249_ec.0207.fits',
#   'HD23249_ec.0208.fits',
#   'HD23249_ec.0210.fits',
#   'HD23249_ec.0247.fits',
#   'HD23249_ec.0248.fits',
#   'HD23249_ec.0249.fits'],
#  'res_filename': ['/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0173/HD23249_ec.0173_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0174/HD23249_ec.0174_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0175/HD23249_ec.0175_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0185/HD23249_ec.0185_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0197/HD23249_ec.0197_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0198/HD23249_ec.0198_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251025/HD23249_ec.0199/HD23249_ec.0199_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251029/HD23249_ec.0071/HD23249_ec.0071_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251029/HD23249_ec.0072/HD23249_ec.0072_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0282/HD23249_ec.0282_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0283/HD23249_ec.0283_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0284/HD23249_ec.0284_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0312/HD23249_ec.0312_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0313/HD23249_ec.0313_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0314/HD23249_ec.0314_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0342/HD23249_ec.0342_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0343/HD23249_ec.0343_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0344/HD23249_ec.0344_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0372/HD23249_ec.0372_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0373/HD23249_ec.0373_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0374/HD23249_ec.0374_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0402/HD23249_ec.0402_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0403/HD23249_ec.0403_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0404/HD23249_ec.0404_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0468/HD23249_ec.0468_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0469/HD23249_ec.0469_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0470/HD23249_ec.0470_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0498/HD23249_ec.0498_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0499/HD23249_ec.0499_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0500/HD23249_ec.0500_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0582/HD23249_ec.0582_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251030/HD23249_ec.0583/HD23249_ec.0583_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0486/HD23249_ec.0486_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0487/HD23249_ec.0487_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0488/HD23249_ec.0488_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0516/HD23249_ec.0516_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0517/HD23249_ec.0517_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0518/HD23249_ec.0518_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0546/HD23249_ec.0546_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0547/HD23249_ec.0547_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0548/HD23249_ec.0548_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0576/HD23249_ec.0576_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0577/HD23249_ec.0577_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251031/HD23249_ec.0578/HD23249_ec.0578_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0258/HD23249_ec.0258_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0259/HD23249_ec.0259_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0260/HD23249_ec.0260_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0279/HD23249_ec.0279_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0280/HD23249_ec.0280_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0281/HD23249_ec.0281_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0435/HD23249_ec.0435_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251101/HD23249_ec.0437/HD23249_ec.0437_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0244/HD23249_ec.0244_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0245/HD23249_ec.0245_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0246/HD23249_ec.0246_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0274/HD23249_ec.0274_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0275/HD23249_ec.0275_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0276/HD23249_ec.0276_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0304/HD23249_ec.0304_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0305/HD23249_ec.0305_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0306/HD23249_ec.0306_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0334/HD23249_ec.0334_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0335/HD23249_ec.0335_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0336/HD23249_ec.0336_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0364/HD23249_ec.0364_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0365/HD23249_ec.0365_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0366/HD23249_ec.0366_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0394/HD23249_ec.0394_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0395/HD23249_ec.0395_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251102/HD23249_ec.0396/HD23249_ec.0396_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0165/HD23249_ec.0165_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0166/HD23249_ec.0166_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0167/HD23249_ec.0167_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0168/HD23249_ec.0168_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0169/HD23249_ec.0169_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0170/HD23249_ec.0170_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0198/HD23249_ec.0198_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0199/HD23249_ec.0199_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0200/HD23249_ec.0200_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0201/HD23249_ec.0201_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0202/HD23249_ec.0202_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0203/HD23249_ec.0203_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0231/HD23249_ec.0231_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0232/HD23249_ec.0232_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0233/HD23249_ec.0233_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0234/HD23249_ec.0234_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0235/HD23249_ec.0235_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0236/HD23249_ec.0236_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0264/HD23249_ec.0264_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0265/HD23249_ec.0265_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0266/HD23249_ec.0266_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0267/HD23249_ec.0267_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0268/HD23249_ec.0268_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251103/HD23249_ec.0269/HD23249_ec.0269_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0158/HD23249_ec.0158_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0159/HD23249_ec.0159_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0160/HD23249_ec.0160_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0188/HD23249_ec.0188_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0189/HD23249_ec.0189_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0190/HD23249_ec.0190_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0191/HD23249_ec.0191_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0192/HD23249_ec.0192_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0193/HD23249_ec.0193_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0221/HD23249_ec.0221_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0222/HD23249_ec.0222_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0223/HD23249_ec.0223_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0224/HD23249_ec.0224_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0225/HD23249_ec.0225_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0226/HD23249_ec.0226_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0245/HD23249_ec.0245_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0246/HD23249_ec.0246_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0247/HD23249_ec.0247_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0248/HD23249_ec.0248_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0249/HD23249_ec.0249_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251104/HD23249_ec.0250/HD23249_ec.0250_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251110/HD23249_ec.0237/HD23249_ec.0237_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251110/HD23249_ec.0240/HD23249_ec.0240_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251111/HD23249_ec.0300/HD23249_ec.0300_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251111/HD23249_ec.0301/HD23249_ec.0301_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251112/HD23249_ec.0261/HD23249_ec.0261_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251112/HD23249_ec.0262/HD23249_ec.0262_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251112/HD23249_ec.0263/HD23249_ec.0263_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0205/HD23249_ec.0205_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0206/HD23249_ec.0206_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0207/HD23249_ec.0207_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0208/HD23249_ec.0208_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251113/HD23249_ec.0210/HD23249_ec.0210_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251114/HD23249_ec.0247/HD23249_ec.0247_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251114/HD23249_ec.0248/HD23249_ec.0248_res1.h5',
#   '/home/holtz/git/pyodine/apo_data/obs_results/UT251114/HD23249_ec.0249/HD23249_ec.0249_res1.h5'],
#  'rv': array([ -77.0984449 ,  -40.33532524,  -30.32140774,   19.16109592,
#          104.50387132,  121.16789583,  135.76820112, 1359.83466754,
#         1369.78272343, 1754.17776235, 1771.79853729, 1789.78232037,
#         1823.2078182 , 1838.07148934, 1863.17456591, 1894.2403708 ,
#         1920.0731505 , 1941.16851051, 1974.32728782, 1993.90399851,
#         2016.32237914, 2048.81339614, 2075.7208829 , 2085.01879434,
#         2144.34684928, 2172.41753119, 2187.24388484, 2220.62172712,
#         2240.6692478 , 2254.09739829, 2294.4583311 , 2302.70789046,
#         2474.50550861, 2501.66081894, 2510.52746976, 2558.09899014,
#         2570.0335888 , 2597.62676602, 2629.99739865, 2653.67539772,
#         2666.82568332, 2702.94286869, 2723.32291999, 2733.50348356,
#         2682.14633814, 2707.02340359, 2728.51266179, 2751.6961715 ,
#         2775.20850844, 2801.91370299, 3097.0889282 , 3136.28846698,
#         3197.94889032, 3220.24828843, 3244.80341163, 3277.54658838,
#         3307.27423677, 3330.43040486, 3368.58990741, 3390.94901995,
#         3409.28357806, 3449.85865731, 3463.92209643, 3495.13999701,
#         3529.48890912, 3536.29492442, 3555.94360205, 3591.55217181,
#         3607.90954424, 3634.348519  , 3536.65986819, 3549.73381596,
#         3578.63497478, 3589.29941666, 3616.65586765, 3634.4801449 ,
#         3669.96073551, 3684.87152338, 3707.21240444, 3723.11894454,
#         3753.30686415, 3776.23722084, 3816.40231028, 3837.79721583,
#         3858.69429273, 3879.82839921, 3904.42660346, 3916.4795878 ,
#         3953.79484564, 3979.36949565, 4000.00980812, 4012.28706544,
#         4031.29187996, 4046.53849271, 4089.48309163, 4100.34384632,
#         4129.678511  , 4165.44023705, 4184.6826968 , 4210.38948841,
#         4226.35084168, 4244.88316661, 4270.99651905, 4333.43473024,
#         4341.0967978 , 4366.95177244, 4392.2510579 , 4408.61890426,
#         4427.07107288, 4459.18171328, 4473.26463309, 4501.06188747,
#         4501.61590601, 4526.8685396 , 4541.49225601, 6662.2301959 ,
#         6696.10009973, 7145.30427291, 7150.57845992, 7584.32961332,
#         7601.93279357, 7628.14297906, 7900.24438737, 7922.54786584,
#         7930.77884113, 7986.1840231 , 7926.21177105, 8404.67959054,
#         8397.58604067, 8369.34780059]),
#  'rv_bc': array([-6727.91308005, -6720.65812447, -6739.55066171, -6726.17625757,
#         -6727.87162863, -6735.24014436, -6743.40886645, -6737.066116  ,
#         -6746.41430576, -6738.29036569, -6739.00735384, -6739.77749437,
#         -6740.95004754, -6745.6444484 , -6740.38622888, -6745.46211325,
#         -6739.91912482, -6739.27075415, -6743.02751245, -6743.87295671,
#         -6741.89959919, -6746.20851319, -6739.55113903, -6750.24500656,
#         -6743.36415193, -6734.3762856 , -6738.55380591, -6738.62722132,
#         -6736.37050478, -6740.26842929, -6750.76623482, -6757.7724839 ,
#         -6743.9475032 , -6737.17996735, -6748.57702328, -6737.45155007,
#         -6745.08834007, -6736.84451919, -6740.13500393, -6734.93959401,
#         -6739.88688927, -6735.611958  , -6732.03064846, -6738.18750963,
#         -6742.80164122, -6737.16113586, -6735.23349659, -6744.59062371,
#         -6741.14339462, -6734.61792356, -6729.77065528, -6726.63326417,
#         -6746.4190343 , -6744.1870105 , -6739.93669273, -6747.86293668,
#         -6738.68500592, -6736.05243758, -6738.25973845, -6736.22736615,
#         -6738.05190952, -6737.1252713 , -6742.67370404, -6730.88402193,
#         -6732.94855881, -6744.51098559, -6742.84499474, -6740.95596747,
#         -6741.33563405, -6731.12572299, -6739.1751472 , -6744.70586961,
#         -6734.65112802, -6744.0106064 , -6736.10397587, -6738.08803675,
#         -6741.94328794, -6747.44063424, -6745.48376616, -6750.86811764,
#         -6741.27421773, -6738.80613145, -6738.94825366, -6737.90222303,
#         -6737.19939794, -6736.84921445, -6732.13630091, -6739.66213567,
#         -6739.861703  , -6733.1092746 , -6730.79997775, -6737.20386258,
#         -6735.63715136, -6737.43499988, -6722.08170538, -6731.08875238,
#         -6721.88058027, -6726.24657091, -6727.53071523, -6722.38312676,
#         -6727.8269002 , -6729.83618642, -6724.20492253, -6719.33979951,
#         -6731.56853379, -6725.36974926, -6720.27170949, -6723.10013055,
#         -6723.62123477, -6723.94949056, -6727.75052255, -6717.30785291,
#         -6734.33107478, -6725.52354255, -6726.8189001 , -6729.38962077,
#         -6724.03299614, -6728.82482657, -6732.95305077, -6736.47040488,
#         -6728.08714032, -6711.24995857, -6844.75331556, -6831.23750068,
#         -6831.99808318, -6786.53419939, -6865.03489497, -6824.13421433,
#         -6840.44387441, -6878.14443162]),
#  'rv_err': array([ 5.08444924,  5.32502954,  5.46887721,  5.19186319,  4.99667665,
#          5.05509958,  5.54379223,  4.63619476,  5.53334422,  4.08249866,
#          3.83043636,  3.54811878,  3.61878136,  3.49147054,  3.60269695,
#          3.74182266,  3.56563604,  3.40824978,  3.53937505,  3.45476345,
#          3.55156224,  3.35788505,  3.52831291,  3.89404921,  3.82144688,
#          3.47583422,  3.61917041,  3.63832146,  3.65185041,  3.71759848,
#          4.39362225,  4.9375745 ,  3.07887612,  3.07573721,  3.34422471,
#          3.1983678 ,  3.03078457,  3.06302965,  3.62865288,  3.26134925,
#          3.37609289,  3.84896413,  3.61829588,  3.85980249,  3.8738394 ,
#          4.13901861,  3.84791836,  4.79589194,  4.42037571,  4.415519  ,
#          5.19739448,  5.71567279,  3.61313636,  3.25118702,  3.04957547,
#          3.29577394,  3.01547063,  3.07142318,  3.20640656,  3.28503176,
#          3.59438507,  3.65141416,  3.29592244,  3.67139575,  4.01076419,
#          4.10831558,  4.27250905,  4.19719846,  4.5896877 ,  4.80644005,
#          3.85930714,  3.77858605,  3.57982047,  3.44122673,  3.46275883,
#          3.57799948,  3.68210719,  4.31963146,  4.82244402,  4.2861206 ,
#          4.42413738,  3.90189942,  3.88821255,  4.17858192,  4.48150918,
#          4.12109244,  3.53904717,  3.69675055,  4.60889436,  4.0347332 ,
#          4.32082876,  4.60616345,  4.90912964,  5.1888323 ,  3.97531794,
#          3.91523767,  3.93346405,  4.02177666,  4.00288134,  4.01974956,
#          3.6992692 ,  3.9432393 ,  4.18302016,  4.32326532,  4.63075383,
#          4.29060422,  4.23445301,  4.44329957,  4.76260438,  5.18736214,
#          4.96766513,  4.82783032,  5.15451411,  5.2638785 ,  5.52845223,
#          6.63450737,  6.51145452,  6.58641975,  6.75382348,  6.59456869,
#          6.79347797,  6.76044485,  9.69663567,  9.37724203,  9.09633649,
#          9.54751234, 10.44508544, 10.3076869 ,  9.92018832,  9.9822624 ]),
#  'rv_err2': array([4.91953746, 4.93326677, 4.92868685, 4.90895651, 4.89905588,
#         4.90726633, 4.93555773, 4.90053124, 4.92074105, 4.89211963,
#         4.89334242, 4.89375874, 4.8909679 , 4.8900394 , 4.8914815 ,
#         4.89393354, 4.89038173, 4.88994491, 4.89333815, 4.89164931,
#         4.89058883, 4.88987563, 4.89029627, 4.89230739, 4.89294892,
#         4.89028638, 4.89047264, 4.89170977, 4.89030782, 4.89006976,
#         4.89238963, 4.9092643 , 4.89010442, 4.8905446 , 4.89011135,
#         4.89025442, 4.8911932 , 4.8899409 , 4.8902339 , 4.88988142,
#         4.89053891, 4.89177451, 4.89092427, 4.89165177, 4.89232688,
#         4.89349886, 4.89299362, 4.89953105, 4.89540447, 4.89747186,
#         4.90104992, 4.92569211, 4.89193706, 4.89108773, 4.89182684,
#         4.89004386, 4.88983671, 4.89844857, 4.8903852 , 4.90858342,
#         4.89231204, 4.8915902 , 4.88987074, 4.89042798, 4.89175235,
#         4.89039097, 4.89422978, 4.89140909, 4.8998052 , 4.89961492,
#         4.89148182, 4.89344464, 4.8926834 , 4.89307804, 4.88999362,
#         4.89021266, 4.89232539, 4.89226889, 4.90053506, 4.89194298,
#         4.89779896, 4.89172351, 4.89212398, 4.90059212, 4.89167319,
#         4.8916889 , 4.89097798, 4.89062042, 4.89630743, 4.89115311,
#         4.89956956, 4.90182831, 4.90383001, 4.91194266, 4.89093927,
#         4.8901783 , 4.89005092, 4.89086569, 4.89058412, 4.89081492,
#         4.88977132, 4.89063516, 4.89086051, 4.89066609, 4.89205647,
#         4.89682694, 4.89040071, 4.8922    , 4.89164233, 4.90954323,
#         4.89617597, 4.89297189, 4.90017589, 4.89956479, 4.91396213,
#         4.98912533, 4.98987866, 5.0133029 , 5.01175296, 5.02805524,
#         5.09474775, 5.03377222, 7.41207888, 7.04887861, 6.99915722,
#         6.6667408 , 7.53858986, 7.18471862, 7.36787175, 7.55514035]),
#  'star_dec': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'star_pmdec': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'star_pmra': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'star_ra': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])}

# %%
plt.scatter(Results.timeseries['bary_date_corr'],Results.timeseries
    ['bary_vel_corr'])
plt.xlim(2460900+75,2460900+90)
plt.figure()
plt.scatter(Results.timeseries['bary_date_corr'],Results.timeseries['rv'])
plt.xlim(2460900+75,2460900+90)
plt.figure()
plt.scatter(Results.timeseries['bary_date_corr'],Results.timeseries['rv_bc'])
plt.xlim(2460900+75,2460900+90)
plt.ylim(-6760,-6710)
# Out:
# (-6760.0, -6710.0)

# %%
from astropy.coordinates import Angle
rastr='3h43m14s'
decstr='-9d45m48s'
ra=Angle(rastr)
dec=Angle(decstr)

# %%
print(ra.degree,dec.degree)
# Out:
# 55.80833333333333 -9.763333333333334

# %%
from astropy.coordinates import SkyCoord, EarthLocation
sc = SkyCoord(ra,dec)
from astropy.time import Time
t=Time('2025-10-30T4:00:00')

# %%
from astropy.time import TimeDelta
import astropy.units as u
for dt in range(0,16) :
    barycorr=sc.radial_velocity_correction(kind='barycentric',obstime=t+TimeDelta(dt*u.day),
                                         location=EarthLocation.of_site('APO'))
    print((t+TimeDelta(dt*u.day)).jd,barycorr)
# Out:
# 2460978.6666666665 6425.092062414667 m / s
# 2460979.6666666665 5979.12715365732 m / s
# 2460980.6666666665 5531.566803172744 m / s
# 2460981.6666666665 5082.574598697603 m / s
# 2460982.6666666665 4632.274370716463 m / s
# 2460983.6666666665 4180.733643099291 m / s
# 2460984.6666666665 3727.955712058978 m / s
# 2460985.6666666665 3273.8884050763927 m / s
# 2460986.6666666665 2818.4510420539473 m / s
# 2460987.6666666665 2361.5718127867963 m / s
# 2460988.6666666665 1903.2219309126367 m / s
# 2460989.6666666665 1443.4347773352395 m / s
# 2460990.6666666665 982.3065278209315 m / s
# 2460991.6666666665 519.9836097226549 m / s
# 2460992.6666666665 56.64619368949149 m / s
# 2460993.6666666665 -407.5053041510477 m / s

# %%
print(barycorr)
# Out:
# -11773.177872276969 m / s
